# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/Daily_Means_Through_2022_cleaned_NEW.csv')
df

# %%
# visualize missing data
import missingno as msno
import matplotlib.pyplot as plt

msno.matrix(df)
plt.show()

# %%
msno.bar(df)
