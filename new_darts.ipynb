# %%
# forecasting with past covariates - we use a couple different new architectures and see what works best
# deep learning used elsewhere, this will just be random forest stuff
# TODO

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly
from darts import TimeSeries
from darts.models import LinearRegressionModel, NaiveSeasonal, NaiveDrift, ExponentialSmoothing, ARIMA
from darts.models import RNNModel, TCNModel, NBEATSModel, TFTModel

# %%
df_pivot = pd.read_csv('Daily_Means_Through_2022_cleaned_NEW.csv')
df_pivot

# %%
# housekeeping
df_pivot['date'] = pd.to_datetime(df_pivot['date'])
df_new = df_pivot.sort_values(by=['site', 'date'])
df_new

# %%
# so BR is NOT continous

df = df_new[df_new['site'] == 'TW']
# drop observation if do is na
#df = df.dropna(subset=['bottom_DO_mg/L'])
print(df["bottom_DO_mg/L"].isnull().sum())
df = df.dropna(subset=['bottom_DO_mg/L'])
print(df.isnull().sum())
print(df)
